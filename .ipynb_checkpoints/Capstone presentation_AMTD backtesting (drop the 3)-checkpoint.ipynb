# %% [markdown]
# <hr style="margin-bottom: 40px;">
#
# # AMDT - Backtesting

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## (A) (B) Simplified

# %%
import pandas as pd
import numpy as np
from datetime import date
from matplotlib import pyplot as plt

df = pd.read_excel("AMTD.xlsx", parse_dates=True, index_col="date")
df.apply(pd.to_numeric, errors='ignore')
df = df.rename(columns=lambda x: x.strip())
df = df.dropna(axis="index",how="all") #drop NaN values. The earliest data starts from 2010-4-5.
#df = df.drop(["AMRSGRF HK Equity", "AMINAGP HK Equity", "AMINCAA HK Equity"],axis=1)
hsi = pd.read_csv("HSI.csv", parse_dates=True, index_col="Date")
hsi = hsi.dropna(axis="index",how="all")
hsi = hsi[(hsi.index > pd.Timestamp(date(2010,4,5)))]

# %%
hsi.plot(figsize=(15,10))
plt.xlabel('Date')
plt.ylabel('HSI Adj Close')
plt.title("Performance of HSI")
# Out:
# Text(0.5, 1.0, 'Performance of HSI')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 1a - Portfolio Optimization for maximal Sharpe ratio

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.expected_returns import mean_historical_return

def backtesting(functionname, reb_mo, duration):
    
    print("---------------------------------Rebalancing Portfolio on " + str(reb_mo) + "---------------------------------")
    end_date = reb_mo + pd.to_timedelta(np.ceil(duration), unit="D")
    train_set = df[(df.index < reb_mo)]
    test_set = df[(df.index >= reb_mo) & (df.index < end_date)]
    hsi_set = hsi[(hsi.index >= reb_mo) & (hsi.index < end_date)]
    S = CovarianceShrinkage(train_set).ledoit_wolf()
    mu = mean_historical_return(train_set)
    test_mu = mean_historical_return(test_set)
    
    if functionname == "1a":
        ef = EfficientFrontier(mu, S)
        ef.max_sharpe()
        weights = ef.clean_weights() 
    
    elif functionname == "1b":
        ef = EfficientFrontier(None, S, weight_bounds=(None, None))
        ef.min_volatility()
        weights = ef.clean_weights()
    
    elif functionname == "2a":
        ef.efficient_risk(target_volatility=0.05)                    
        weights = ef.clean_weights()
        
    elif functionname == "2b":
        ef.efficient_return(target_return=0.05, market_neutral=True)
        weights = ef.clean_weights()
        
    print("----------Train Set Performance ---------------")
    ret,vol,sharpe = ef.portfolio_performance(verbose=True)
    print("----------Actual Performance ---------------")
    ret_data = test_set.pct_change()[1:]
    weighted_returns = (weights * ret_data)
    port_ret = weighted_returns.sum(axis=1)/len(ret_data)*252
    print("Portfolio return in test year: " + str(sum(port_ret)*100) + " %")
    diff = (sum(port_ret) - ret)*100
    print("Portfolio return compared to train set: " + str(diff) + " %")
    perch = diff/ret
    print("Percentage change compared to train set: " + str(perch) + " %")
    
    #port_vol = weighted_returns.std(ddof=0)
    #print("Portfolio Volatility: " + str(port_vol) + " %")
    
    print("----------Comparison with Benchmark---------------")
    ret_bench = hsi_set.pct_change()[1:]
    total_bench_ret = ret_bench.sum(axis=1)/len(ret_bench)*252
    print("Benchmark return in test year: " + str(sum(total_bench_ret)*100) + " %")
    
    diff = (sum(port_ret) - sum(total_bench_ret))*100
    print("Portfolio return compared to benchmark: " + str(diff) + " %")

    
    print("----------Portfolio Weighting---------------")
    print("Porfolio weightings:" + str(weights))

# %% [markdown]
# ## 1st five-year Backtesting (for Function 1a)
# ### Run the function - what's the weighting for this period?

# %%
reb_mo = pd.Timestamp(date(2012,7,1))
duration = 30

backtesting("1a", reb_mo, duration)
# Out:
# ---------------------------------Rebalancing Portfolio on 2012-07-01 00:00:00---------------------------------
# ----------Train Set Performance ---------------
# Expected annual return: 3.1%
# Annual volatility: 17.4%
# Sharpe Ratio: 0.06
# ----------Actual Performance ---------------
# Portfolio return in test year: -13.731980585134634 %
# Portfolio return compared to train set: -16.862398121181315 %
# Percentage change compared to train set: -538.6629076476606 %
# ----------Comparison with Benchmark---------------
# Benchmark return in test year: -8.021527921201809 %
# Portfolio return compared to benchmark: -5.710452663932824 %
# ----------Portfolio Weighting---------------
# Porfolio weightings:OrderedDict([('AMRCBLF HK Equity', 0.0), ('AMRCASF HK Equity', 0.0), ('AMRDALF HK Equity', 0.0), ('AMRCGRF HK Equity', 0.63633), ('AMRSGRF HK Equity', 0.0), ('AMINAGP HK Equity', 0.0), ('AMINASF HK Equity', 0.36367), ('AMINCAA HK Equity', 0.0), ('AMINEUF HK Equity', 0.0), ('AMIGBOF HK Equity', 0.0), ('AMIHKCF HK Equity', 0.0), ('AMIMCOF HK Equity', 0.0), ('AMIT18R HK Equity', 0.0), ('AMIT28R HK Equity', 0.0), ('AMIT38R HK Equity', 0.0), ('AMIT48R HK Equity', 0.0)])

# %%
#pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
#mu.plot.barh(figsize=(10,6)) 
#test_mu.plot.barh(figsize=(10,6))

#plotting.plot_covariance(S, plot_correlation=True)
#mu.plot.barh(figsize=(10,6))

plt.style.use('fivethirtyeight')
df[(df.index < reb_mo)].plot(figsize=(15,10))
plt.xlabel('Date')
plt.ylabel('Fund NAV')
plt.title("Performance of AMTD Funds before Rebalancing Portfolio")
# Out:
# Text(0.5, 1.0, 'Performance of AMTD Funds before Rebalancing Portfolio')

# %%
#pd.Series(cleanweight1a).plot.pie(figsize=(5,5))
#mu.plot.barh(figsize=(10,6)) 
#test_mu.plot.barh(figsize=(10,6))

#plotting.plot_covariance(S, plot_correlation=True)
#mu.plot.barh(figsize=(10,6))

# %%
#perch_all = [perch1,perch2,perch3,perch4,perch5,perch6]
#mean_perch = sum(perch_all) / len(perch_all)
#print( "Function 1a Average error (%): " + str(mean_perch))
#print( "Function 1a Accuracy (%): " + str(100-mean_perch))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 2a - Portfolio Optimization with given Risk Tolerance

# %%
ef = EfficientFrontier(mu, S)

ef.efficient_risk(target_volatility=0.1) #input desired volatility - default as ten percent
weights = ef.clean_weights()
weights

pd.Series(weights).plot.pie(figsize=(5,5))
plt.title("Fund Portfolio")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b8bbb36d9bd1> in <module>
# ----> 1 ef = EfficientFrontier(mu, S)
#       2
#       3 ef.efficient_risk(target_volatility=0.1) #input desired volatility - default as ten percent
#       4 weights = ef.clean_weights()
#       5 weights
#
# NameError: name 'mu' is not defined

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## 1st five-year Backtesting  (for Function 2a)

# %% [markdown]
# ### Run the function - what's the weighting for this period?

# %%
ef = EfficientFrontier(mu6, S6)

weight2a = ef.max_sharpe() #raw weights
cleanweight1a = ef.clean_weights() #cleaned weights
print(cleanweight1a)
print("Performance of function 1a portfolio in train period:")
pd.Series(cleanweight1a).plot.pie(figsize=(5,5))

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Train period.

# %%
ret,vol,sharpe = ef.portfolio_performance(verbose=True)

mu1.plot.barh(figsize=(10,6))    #return of each funds from 2010 to 2014.

# %% [markdown]
# ### Comparison - Performance of Portfolio during the Validation period.

# %%
#calculate the asset returns in our portfolio.
ret_data = tone.pct_change()[1:]

#calculate the weighted returns of our assets.
weighted_returns = (cleanweight1a * ret_data)

#portfolio returns are simply the sum of the weighted returns of the assets. So lets add the rows.
port_ret = weighted_returns.sum(axis=1)
print("Portfolio return in test year(%):")
print(sum(port_ret)*100)
print("Portfolio return compared to previous year(+- %):")
print((sum(port_ret) - ret)*100)

tmu1.plot.barh(figsize=(10,6))  #return of each fund from 2014 to 2015. (test period)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 3 - Minimise risk for a given return

# %%
ef = EfficientFrontier(mu, S, weight_bounds=(None, None))
ef.efficient_return(target_return=0.07, market_neutral=True)
weights = ef.clean_weights()
weights

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Plotting Efficient Frontier

# %%
from pypfopt import CLA, plotting

cla = CLA(mu, S)
cla.max_sharpe()
cla.portfolio_performance(verbose=True);

# %%
ax = plotting.plot_efficient_frontier(cla, showfig=False)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # This scheme in a nutshell:

# %%
risktolerance, annualreturn = [], []
for rt2 in np.arange(0.012, 1, 0.001):
    ef = EfficientFrontier(mu, S)
    ef.efficient_risk(target_volatility=rt2)
    weights = ef.clean_weights()
    ret, volatility, Sharpe = ef.portfolio_performance(verbose=True)
    annualreturn.append(ret)
    risktolerance.append(rt2)

# %%
plt.plot(annualreturn, risktolerance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
