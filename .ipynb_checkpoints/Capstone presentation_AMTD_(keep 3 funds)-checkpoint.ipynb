# %% [markdown]
# <hr style="margin-bottom: 40px;">
#
# # AMDT - MPF Portfolio Optimization Model

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## (A) Understanding the data

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

#plt.style.use('fivethirtyeight')
df = pd.read_excel("AMTD.xlsx", parse_dates=True, index_col="date")

# %%
df.apply(pd.to_numeric, errors='ignore')
df = df.rename(columns=lambda x: x.strip())
df
# Out:
#             AMRCBLF HK Equity  AMRCASF HK Equity  AMRDALF HK Equity  \
# date
# 2000-12-01                NaN                NaN                NaN
# 2000-12-04                NaN                NaN                NaN
# 2000-12-05                NaN                NaN                NaN
# 2000-12-06                NaN                NaN                NaN
# 2000-12-07                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27              16.39              13.39              13.18
# 2020-07-28              16.48              13.43              13.18
# 2020-07-29              16.52              13.45              13.20
# 2020-07-30              16.46              13.44              13.19
# 2020-07-31              16.45              13.43              13.19
#
#             AMRCGRF HK Equity  AMRSGRF HK Equity  AMINAGP HK Equity  \
# date
# 2000-12-01                NaN                NaN                NaN
# 2000-12-04                NaN                NaN                NaN
# 2000-12-05                NaN                NaN                NaN
# 2000-12-06                NaN                NaN                NaN
# 2000-12-07                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27              18.00              14.95            11.6316
# 2020-07-28              18.12              15.01            11.6361
# 2020-07-29              18.17              15.04            11.6509
# 2020-07-30              18.08              15.00            11.6548
# 2020-07-31              18.05              15.00            11.6575
#
#             AMINASF HK Equity  AMINCAA HK Equity  AMINEUF HK Equity  \
# date
# 2000-12-01                NaN                NaN                NaN
# 2000-12-04                NaN                NaN                NaN
# 2000-12-05                NaN                NaN                NaN
# 2000-12-06                NaN                NaN                NaN
# 2000-12-07                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27            17.4413            12.0733            14.6092
# 2020-07-28            17.6109            12.0575            14.6926
# 2020-07-29            17.5575            12.1054            14.6512
# 2020-07-30            17.6800            12.0709            14.3242
# 2020-07-31            17.5798            12.0833            14.2983
#
#             AMIGBOF HK Equity  AMIHKCF HK Equity  AMIMCOF HK Equity  \
# date
# 2000-12-01                NaN                NaN                NaN
# 2000-12-04                NaN                NaN                NaN
# 2000-12-05                NaN                NaN                NaN
# 2000-12-06                NaN                NaN                NaN
# 2000-12-07                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27            11.4594            16.7664            10.1914
# 2020-07-28            11.4906            16.9794            10.1913
# 2020-07-29            11.4927            17.0443            10.1913
# 2020-07-30            11.5174            16.9541            10.1913
# 2020-07-31            11.5579            16.9242            10.1910
#
#             AMIT18R HK Equity  AMIT28R HK Equity  AMIT38R HK Equity  \
# date
# 2000-12-01                NaN                NaN                NaN
# 2000-12-04                NaN                NaN                NaN
# 2000-12-05                NaN                NaN                NaN
# 2000-12-06                NaN                NaN                NaN
# 2000-12-07                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27            14.1907            15.3507            16.8613
# 2020-07-28            14.2466            15.4165            16.9393
# 2020-07-29            14.2541            15.4267            16.9526
# 2020-07-30            14.2433            15.3936            16.8905
# 2020-07-31            14.2689            15.4083            16.8911
#
#             AMIT48R HK Equity
# date
# 2000-12-01                NaN
# 2000-12-04                NaN
# 2000-12-05                NaN
# 2000-12-06                NaN
# 2000-12-07                NaN
# ...                       ...
# 2020-07-27            17.6810
# 2020-07-28            17.7709
# 2020-07-29            17.7882
# 2020-07-30            17.6938
# 2020-07-31            17.6765
#
# [5053 rows x 16 columns]

# %%
df.tail()
# Out:
#             AMRCBLF HK Equity  AMRCASF HK Equity  AMRDALF HK Equity  \
# date
# 2020-07-27              16.39              13.39              13.18
# 2020-07-28              16.48              13.43              13.18
# 2020-07-29              16.52              13.45              13.20
# 2020-07-30              16.46              13.44              13.19
# 2020-07-31              16.45              13.43              13.19
#
#             AMRCGRF HK Equity  AMRSGRF HK Equity  AMINAGP HK Equity  \
# date
# 2020-07-27              18.00              14.95            11.6316
# 2020-07-28              18.12              15.01            11.6361
# 2020-07-29              18.17              15.04            11.6509
# 2020-07-30              18.08              15.00            11.6548
# 2020-07-31              18.05              15.00            11.6575
#
#             AMINASF HK Equity  AMINCAA HK Equity  AMINEUF HK Equity  \
# date
# 2020-07-27            17.4413            12.0733            14.6092
# 2020-07-28            17.6109            12.0575            14.6926
# 2020-07-29            17.5575            12.1054            14.6512
# 2020-07-30            17.6800            12.0709            14.3242
# 2020-07-31            17.5798            12.0833            14.2983
#
#             AMIGBOF HK Equity  AMIHKCF HK Equity  AMIMCOF HK Equity  \
# date
# 2020-07-27            11.4594            16.7664            10.1914
# 2020-07-28            11.4906            16.9794            10.1913
# 2020-07-29            11.4927            17.0443            10.1913
# 2020-07-30            11.5174            16.9541            10.1913
# 2020-07-31            11.5579            16.9242            10.1910
#
#             AMIT18R HK Equity  AMIT28R HK Equity  AMIT38R HK Equity  \
# date
# 2020-07-27            14.1907            15.3507            16.8613
# 2020-07-28            14.2466            15.4165            16.9393
# 2020-07-29            14.2541            15.4267            16.9526
# 2020-07-30            14.2433            15.3936            16.8905
# 2020-07-31            14.2689            15.4083            16.8911
#
#             AMIT48R HK Equity
# date
# 2020-07-27            17.6810
# 2020-07-28            17.7709
# 2020-07-29            17.7882
# 2020-07-30            17.6938
# 2020-07-31            17.6765

# %%
df.info() #dropped the funds that have not enough data for analysis. #no need for type conversion.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5053 entries, 2000-12-01 to 2020-07-31
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AMRCBLF HK Equity  2617 non-null   float64
#  1   AMRCASF HK Equity  2617 non-null   float64
#  2   AMRDALF HK Equity  2617 non-null   float64
#  3   AMRCGRF HK Equity  2617 non-null   float64
#  4   AMRSGRF HK Equity  189 non-null    float64
#  5   AMINAGP HK Equity  684 non-null    float64
#  6   AMINASF HK Equity  2617 non-null   float64
#  7   AMINCAA HK Equity  684 non-null    float64
#  8   AMINEUF HK Equity  2617 non-null   float64
#  9   AMIGBOF HK Equity  2617 non-null   float64
#  10  AMIHKCF HK Equity  2617 non-null   float64
#  11  AMIMCOF HK Equity  2617 non-null   float64
#  12  AMIT18R HK Equity  2543 non-null   float64
#  13  AMIT28R HK Equity  2617 non-null   float64
#  14  AMIT38R HK Equity  2601 non-null   float64
#  15  AMIT48R HK Equity  2617 non-null   float64
# dtypes: float64(16)
# memory usage: 671.1 KB

# %%
#df = df.drop(["AMRSGRF HK Equity", "AMINAGP HK Equity", "AMINCAA HK Equity"],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5053 entries, 2000-12-01 to 2020-07-31
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AMRCBLF HK Equity  2617 non-null   float64
#  1   AMRCASF HK Equity  2617 non-null   float64
#  2   AMRDALF HK Equity  2617 non-null   float64
#  3   AMRCGRF HK Equity  2617 non-null   float64
#  4   AMRSGRF HK Equity  189 non-null    float64
#  5   AMINAGP HK Equity  684 non-null    float64
#  6   AMINASF HK Equity  2617 non-null   float64
#  7   AMINCAA HK Equity  684 non-null    float64
#  8   AMINEUF HK Equity  2617 non-null   float64
#  9   AMIGBOF HK Equity  2617 non-null   float64
#  10  AMIHKCF HK Equity  2617 non-null   float64
#  11  AMIMCOF HK Equity  2617 non-null   float64
#  12  AMIT18R HK Equity  2543 non-null   float64
#  13  AMIT28R HK Equity  2617 non-null   float64
#  14  AMIT38R HK Equity  2601 non-null   float64
#  15  AMIT48R HK Equity  2617 non-null   float64
# dtypes: float64(16)
# memory usage: 671.1 KB

# %%
df.tail()  #check if funds are still in operation till now
# Out:
#             AMRCBLF HK Equity  AMRCASF HK Equity  AMRDALF HK Equity  \
# date
# 2020-07-27              16.39              13.39              13.18
# 2020-07-28              16.48              13.43              13.18
# 2020-07-29              16.52              13.45              13.20
# 2020-07-30              16.46              13.44              13.19
# 2020-07-31              16.45              13.43              13.19
#
#             AMRCGRF HK Equity  AMRSGRF HK Equity  AMINAGP HK Equity  \
# date
# 2020-07-27              18.00              14.95            11.6316
# 2020-07-28              18.12              15.01            11.6361
# 2020-07-29              18.17              15.04            11.6509
# 2020-07-30              18.08              15.00            11.6548
# 2020-07-31              18.05              15.00            11.6575
#
#             AMINASF HK Equity  AMINCAA HK Equity  AMINEUF HK Equity  \
# date
# 2020-07-27            17.4413            12.0733            14.6092
# 2020-07-28            17.6109            12.0575            14.6926
# 2020-07-29            17.5575            12.1054            14.6512
# 2020-07-30            17.6800            12.0709            14.3242
# 2020-07-31            17.5798            12.0833            14.2983
#
#             AMIGBOF HK Equity  AMIHKCF HK Equity  AMIMCOF HK Equity  \
# date
# 2020-07-27            11.4594            16.7664            10.1914
# 2020-07-28            11.4906            16.9794            10.1913
# 2020-07-29            11.4927            17.0443            10.1913
# 2020-07-30            11.5174            16.9541            10.1913
# 2020-07-31            11.5579            16.9242            10.1910
#
#             AMIT18R HK Equity  AMIT28R HK Equity  AMIT38R HK Equity  \
# date
# 2020-07-27            14.1907            15.3507            16.8613
# 2020-07-28            14.2466            15.4165            16.9393
# 2020-07-29            14.2541            15.4267            16.9526
# 2020-07-30            14.2433            15.3936            16.8905
# 2020-07-31            14.2689            15.4083            16.8911
#
#             AMIT48R HK Equity
# date
# 2020-07-27            17.6810
# 2020-07-28            17.7709
# 2020-07-29            17.7882
# 2020-07-30            17.6938
# 2020-07-31            17.6765

# %%
df.dropna(axis="index",how="all") #drop NaN values. The earliest data starts from 2010-4-5.
# Out:
#             AMRCBLF HK Equity  AMRCASF HK Equity  AMRDALF HK Equity  \
# date
# 2010-04-05              11.08              10.54              10.13
# 2010-04-06              11.20              10.60              10.15
# 2010-04-07              11.21              10.57              10.13
# 2010-04-08              11.21              10.57              10.13
# 2010-04-09              11.24              10.58              10.14
# ...                       ...                ...                ...
# 2020-07-27              16.39              13.39              13.18
# 2020-07-28              16.48              13.43              13.18
# 2020-07-29              16.52              13.45              13.20
# 2020-07-30              16.46              13.44              13.19
# 2020-07-31              16.45              13.43              13.19
#
#             AMRCGRF HK Equity  AMRSGRF HK Equity  AMINAGP HK Equity  \
# date
# 2010-04-05              11.39                NaN                NaN
# 2010-04-06              11.54                NaN                NaN
# 2010-04-07              11.58                NaN                NaN
# 2010-04-08              11.57                NaN                NaN
# 2010-04-09              11.60                NaN                NaN
# ...                       ...                ...                ...
# 2020-07-27              18.00              14.95            11.6316
# 2020-07-28              18.12              15.01            11.6361
# 2020-07-29              18.17              15.04            11.6509
# 2020-07-30              18.08              15.00            11.6548
# 2020-07-31              18.05              15.00            11.6575
#
#             AMINASF HK Equity  AMINCAA HK Equity  AMINEUF HK Equity  \
# date
# 2010-04-05            11.7935                NaN            11.0679
# 2010-04-06            11.9296                NaN            11.1473
# 2010-04-07            11.9804                NaN            11.1465
# 2010-04-08            11.9458                NaN            11.1507
# 2010-04-09            12.0070                NaN            11.1041
# ...                       ...                ...                ...
# 2020-07-27            17.4413            12.0733            14.6092
# 2020-07-28            17.6109            12.0575            14.6926
# 2020-07-29            17.5575            12.1054            14.6512
# 2020-07-30            17.6800            12.0709            14.3242
# 2020-07-31            17.5798            12.0833            14.2983
#
#             AMIGBOF HK Equity  AMIHKCF HK Equity  AMIMCOF HK Equity  \
# date
# 2010-04-05            10.1219            11.3104             9.9998
# 2010-04-06            10.1388            11.4125             9.9998
# 2010-04-07            10.0975            11.4125             9.9998
# 2010-04-08            10.0639            11.3053             9.9998
# 2010-04-09            10.0841            11.3910             9.9998
# ...                       ...                ...                ...
# 2020-07-27            11.4594            16.7664            10.1914
# 2020-07-28            11.4906            16.9794            10.1913
# 2020-07-29            11.4927            17.0443            10.1913
# 2020-07-30            11.5174            16.9541            10.1913
# 2020-07-31            11.5579            16.9242            10.1910
#
#             AMIT18R HK Equity  AMIT28R HK Equity  AMIT38R HK Equity  \
# date
# 2010-04-05                NaN            11.0246                NaN
# 2010-04-06                NaN            11.1061                NaN
# 2010-04-07                NaN            11.1087                NaN
# 2010-04-08                NaN            11.0658                NaN
# 2010-04-09                NaN            11.0880                NaN
# ...                       ...                ...                ...
# 2020-07-27            14.1907            15.3507            16.8613
# 2020-07-28            14.2466            15.4165            16.9393
# 2020-07-29            14.2541            15.4267            16.9526
# 2020-07-30            14.2433            15.3936            16.8905
# 2020-07-31            14.2689            15.4083            16.8911
#
#             AMIT48R HK Equity
# date
# 2010-04-05            11.4454
# 2010-04-06            11.5629
# 2010-04-07            11.5901
# 2010-04-08            11.5434
# 2010-04-09            11.5662
# ...                       ...
# 2020-07-27            17.6810
# 2020-07-28            17.7709
# 2020-07-29            17.7882
# 2020-07-30            17.6938
# 2020-07-31            17.6765
#
# [2617 rows x 16 columns]

# %%
describe = df.describe()
describe = pd.DataFrame(describe)
describe = describe.T
describe
# Out:
#                     count       mean       std      min       25%      50%  \
# AMRCBLF HK Equity  2617.0  13.008781  1.598254   9.8100  11.77000  12.9200
# AMRCASF HK Equity  2617.0  11.435797  0.745137   9.8000  10.90000  11.3700
# AMRDALF HK Equity  2617.0  11.426458  0.802417   9.9200  10.64000  11.5500
# AMRCGRF HK Equity  2617.0  13.984215  2.066649   9.7000  12.40000  13.9200
# AMRSGRF HK Equity   189.0  13.985450  0.574546  12.1500  13.73000  14.0800
# AMINAGP HK Equity   684.0  10.598258  0.432762  10.0079  10.24310  10.3835
# AMINASF HK Equity  2617.0  14.396799  1.853161   9.7338  13.11580  14.1053
# AMINCAA HK Equity   684.0  11.066338  0.444722   9.6052  10.81795  11.0212
# AMINEUF HK Equity  2617.0  14.393210  2.706996   9.3008  11.60490  14.9428
# AMIGBOF HK Equity  2617.0  10.355622  0.312357   9.6204  10.16510  10.3113
# AMIHKCF HK Equity  2617.0  13.331739  2.285998   8.4879  11.65750  12.7108
# AMIMCOF HK Equity  2617.0  10.022405  0.044556   9.9988  10.00070  10.0075
# AMIT18R HK Equity  2543.0  12.211078  1.050875  10.0438  11.33455  12.2228
# AMIT28R HK Equity  2617.0  12.989095  1.438767  10.1290  11.79500  13.0005
# AMIT38R HK Equity  2601.0  13.801791  2.009521   9.9298  12.17960  13.7095
# AMIT48R HK Equity  2617.0  14.297824  2.400255   9.6469  12.42920  14.1643
#
#                        75%      max
# AMRCBLF HK Equity  14.2800  16.8100
# AMRCASF HK Equity  11.9700  13.4500
# AMRDALF HK Equity  12.0300  13.2300
# AMRCGRF HK Equity  15.6700  19.0500
# AMRSGRF HK Equity  14.3300  15.0400
# AMINAGP HK Equity  10.9841  11.6575
# AMINASF HK Equity  15.5792  18.4949
# AMINCAA HK Equity  11.3318  12.1183
# AMINEUF HK Equity  16.6873  19.5604
# AMIGBOF HK Equity  10.5249  11.5579
# AMIHKCF HK Equity  15.3755  19.2683
# AMIMCOF HK Equity  10.0095  10.1914
# AMIT18R HK Equity  12.9704  14.3563
# AMIT28R HK Equity  14.1509  15.9285
# AMIT38R HK Equity  15.5069  17.9378
# AMIT48R HK Equity  16.2299  19.4558

# %%
# get a list of all the column names 
indexNamesArr = describe.index.values
# convert ndarray to list
listOfRowIndexLabels = list(indexNamesArr)

coord = [(0.038802, 1.598254),( 0.023617, 0.745137),( 0.025753, 0.802417),( 0.045350, 2.066649),( 0.106415, 0.574546),( 0.053244, 0.432762),( 0.039204, 1.853161),( 0.059571, 0.444722),( 0.024976, 2.706996),( 0.012862, 0.312357),( 0.039587, 2.285998),( 0.001826, 0.044556),( 0.027979, 1.050875),( 0.032775, 1.438767),( 0.040590, 2.009521),( 0.042759, 2.400255)]
labels = listOfRowIndexLabels

def plot_with_labels(coord, labels):
    assert len(coord) == len(labels), 'coord len is not equal to labels len'
    plt.figure(figsize=(10,10))
    plt.xlabel('Mean historic return')
    plt.ylabel('volatility')
    plt.title("Performance of AMTD Funds")
    plt
    for i, label in enumerate(labels): #get (0, label)
        x, y = coord[i] #2 dim
        plt.scatter(x, y,)
                #
        plt.annotate(label,
                xy=(x, y), #show point 
                xytext=(5, 2), #show annotate
                textcoords='offset points',
                ha='right',
                va='bottom')
    plt.show()
    
plot_with_labels(coord, labels)

# %%
plt.style.use('fivethirtyeight')
df.plot(figsize=(15,10))
plt.xlabel('Date')
plt.ylabel('Fund NAV')
plt.title("Performance of AMTD Funds")
# Out:
# Text(0.5, 1.0, 'Performance of AMTD Funds')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## (B) - Data Modelling

# %% [markdown]
# ### Efficient Frontier - calculating expected return and risk matrix

# %%
#!pip install PyPortfolioOpt

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting

# %%
from pypfopt.risk_models import CovarianceShrinkage
S = CovarianceShrinkage(df).ledoit_wolf()

# %%
S
# Out:
#                    AMRCBLF HK Equity  AMRCASF HK Equity  AMRDALF HK Equity  \
# AMRCBLF HK Equity       1.152050e-02       4.958781e-03           0.003217
# AMRCASF HK Equity       4.958781e-03       2.771082e-03           0.001543
# AMRDALF HK Equity       3.216918e-03       1.543422e-03           0.010364
# AMRCGRF HK Equity       1.439527e-02       6.136865e-03           0.004086
# AMRSGRF HK Equity       1.388575e-03       6.480992e-04           0.000579
# AMINAGP HK Equity       6.980105e-04       3.789308e-04           0.000288
# AMINASF HK Equity       1.174977e-02       4.980941e-03           0.003561
# AMINCAA HK Equity       2.573743e-03       1.077846e-03           0.000973
# AMINEUF HK Equity       1.450004e-02       5.627600e-03           0.004191
# AMIGBOF HK Equity       1.969717e-04       5.144499e-04           0.000158
# AMIHKCF HK Equity       1.680794e-02       6.994509e-03           0.004621
# AMIMCOF HK Equity       5.009496e-07       7.035790e-07           0.000002
# AMIT18R HK Equity       1.083221e-03       5.295657e-04           0.000406
# AMIT28R HK Equity       8.175273e-03       3.556747e-03           0.002298
# AMIT38R HK Equity       1.056702e-02       4.447426e-03           0.002959
# AMIT48R HK Equity       1.305535e-02       5.380151e-03           0.003638
#
#                    AMRCGRF HK Equity  AMRSGRF HK Equity  AMINAGP HK Equity  \
# AMRCBLF HK Equity       1.439527e-02       1.388575e-03       6.980105e-04
# AMRCASF HK Equity       6.136865e-03       6.480992e-04       3.789308e-04
# AMRDALF HK Equity       4.085953e-03       5.786689e-04       2.880178e-04
# AMRCGRF HK Equity       1.890105e-02       1.747596e-03       8.506925e-04
# AMRSGRF HK Equity       1.747596e-03       1.138786e-03       3.817821e-04
# AMINAGP HK Equity       8.506925e-04       3.817821e-04       4.754969e-04
# AMINASF HK Equity       1.508987e-02       1.595479e-03       6.721545e-04
# AMINCAA HK Equity       3.316175e-03       1.225183e-03       8.021902e-04
# AMINEUF HK Equity       1.935095e-02       2.172750e-03       1.057929e-03
# AMIGBOF HK Equity      -1.325922e-05       9.794823e-05       1.576122e-04
# AMIHKCF HK Equity       2.177163e-02       1.723158e-03       6.413722e-04
# AMIMCOF HK Equity       4.678262e-07       2.447462e-07       7.156192e-07
# AMIT18R HK Equity       1.334548e-03       6.369258e-04       2.769638e-04
# AMIT28R HK Equity       1.058066e-02       9.195063e-04       5.085065e-04
# AMIT38R HK Equity       1.377311e-02       1.215109e-03       6.341687e-04
# AMIT48R HK Equity       1.709608e-02       1.521235e-03       7.649247e-04
#
#                    AMINASF HK Equity  AMINCAA HK Equity  AMINEUF HK Equity  \
# AMRCBLF HK Equity           0.011750       2.573743e-03           0.014500
# AMRCASF HK Equity           0.004981       1.077846e-03           0.005628
# AMRDALF HK Equity           0.003561       9.725065e-04           0.004191
# AMRCGRF HK Equity           0.015090       3.316175e-03           0.019351
# AMRSGRF HK Equity           0.001595       1.225183e-03           0.002173
# AMINAGP HK Equity           0.000672       8.021902e-04           0.001058
# AMINASF HK Equity           0.031975       2.518180e-03           0.018758
# AMINCAA HK Equity           0.002518       3.101280e-03           0.004414
# AMINEUF HK Equity           0.018758       4.413705e-03           0.038638
# AMIGBOF HK Equity           0.000723       4.158581e-05          -0.000028
# AMIHKCF HK Equity           0.020435       2.667511e-03           0.018551
# AMIMCOF HK Equity          -0.000002      -3.507296e-08          -0.000003
# AMIT18R HK Equity           0.001301       7.991650e-04           0.001504
# AMIT28R HK Equity           0.009727       1.769029e-03           0.012350
# AMIT38R HK Equity           0.012443       2.387778e-03           0.016240
# AMIT48R HK Equity           0.015263       3.031133e-03           0.020152
#
#                    AMIGBOF HK Equity  AMIHKCF HK Equity  AMIMCOF HK Equity  \
# AMRCBLF HK Equity           0.000197           0.016808       5.009496e-07
# AMRCASF HK Equity           0.000514           0.006995       7.035790e-07
# AMRDALF HK Equity           0.000158           0.004621       1.921481e-06
# AMRCGRF HK Equity          -0.000013           0.021772       4.678262e-07
# AMRSGRF HK Equity           0.000098           0.001723       2.447462e-07
# AMINAGP HK Equity           0.000158           0.000641       7.156192e-07
# AMINASF HK Equity           0.000723           0.020435      -2.157418e-06
# AMINCAA HK Equity           0.000042           0.002668      -3.507296e-08
# AMINEUF HK Equity          -0.000028           0.018551      -2.672501e-06
# AMIGBOF HK Equity           0.001299           0.000293       1.737780e-06
# AMIHKCF HK Equity           0.000293           0.035680       1.285357e-06
# AMIMCOF HK Equity           0.000002           0.000001       1.250661e-04
# AMIT18R HK Equity           0.000188           0.001359       5.041316e-07
# AMIT28R HK Equity           0.000703           0.013298       9.266269e-07
# AMIT38R HK Equity           0.000524           0.017147       6.406066e-07
# AMIT48R HK Equity           0.000376           0.021157       3.201687e-07
#
#                    AMIT18R HK Equity  AMIT28R HK Equity  AMIT38R HK Equity  \
# AMRCBLF HK Equity       1.083221e-03       8.175273e-03       1.056702e-02
# AMRCASF HK Equity       5.295657e-04       3.556747e-03       4.447426e-03
# AMRDALF HK Equity       4.063781e-04       2.297943e-03       2.959013e-03
# AMRCGRF HK Equity       1.334548e-03       1.058066e-02       1.377311e-02
# AMRSGRF HK Equity       6.369258e-04       9.195063e-04       1.215109e-03
# AMINAGP HK Equity       2.769638e-04       5.085065e-04       6.341687e-04
# AMINASF HK Equity       1.301106e-03       9.726784e-03       1.244274e-02
# AMINCAA HK Equity       7.991650e-04       1.769029e-03       2.387778e-03
# AMINEUF HK Equity       1.504205e-03       1.235007e-02       1.623998e-02
# AMIGBOF HK Equity       1.876003e-04       7.027191e-04       5.243537e-04
# AMIHKCF HK Equity       1.358550e-03       1.329812e-02       1.714748e-02
# AMIMCOF HK Equity       5.041316e-07       9.266269e-07       6.406066e-07
# AMIT18R HK Equity       4.095934e-03       7.596222e-04       9.611867e-04
# AMIT28R HK Equity       7.596222e-04       7.133982e-03       8.856915e-03
# AMIT38R HK Equity       9.611867e-04       8.856915e-03       1.153779e-02
# AMIT48R HK Equity       1.170106e-03       1.080130e-02       1.391660e-02
#
#                    AMIT48R HK Equity
# AMRCBLF HK Equity       1.305535e-02
# AMRCASF HK Equity       5.380151e-03
# AMRDALF HK Equity       3.637844e-03
# AMRCGRF HK Equity       1.709608e-02
# AMRSGRF HK Equity       1.521235e-03
# AMINAGP HK Equity       7.649247e-04
# AMINASF HK Equity       1.526318e-02
# AMINCAA HK Equity       3.031133e-03
# AMINEUF HK Equity       2.015225e-02
# AMIGBOF HK Equity       3.756018e-04
# AMIHKCF HK Equity       2.115703e-02
# AMIMCOF HK Equity       3.201687e-07
# AMIT18R HK Equity       1.170106e-03
# AMIT28R HK Equity       1.080130e-02
# AMIT38R HK Equity       1.391660e-02
# AMIT48R HK Equity       1.740434e-02

# %%
plotting.plot_covariance(S, plot_correlation=True)

# %%
#Calculate the expected returns and the annualised sample covariance matrix of daily asset returns.

from pypfopt.expected_returns import mean_historical_return
mu = mean_historical_return(df)

# %%
mu
# Out:
# AMRCBLF HK Equity    0.038802
# AMRCASF HK Equity    0.023617
# AMRDALF HK Equity    0.025753
# AMRCGRF HK Equity    0.045350
# AMRSGRF HK Equity    0.106415
# AMINAGP HK Equity    0.053244
# AMINASF HK Equity    0.039204
# AMINCAA HK Equity    0.059571
# AMINEUF HK Equity    0.024976
# AMIGBOF HK Equity    0.012862
# AMIHKCF HK Equity    0.039587
# AMIMCOF HK Equity    0.001826
# AMIT18R HK Equity    0.027979
# AMIT28R HK Equity    0.032775
# AMIT38R HK Equity    0.040590
# AMIT48R HK Equity    0.042759
# dtype: float64

# %%
mu.plot.barh(figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 1a - Portfolio Optimization for maximal Sharpe ratio
#
# ### i.e. What combo of funds to choose within a scheme to earn the most and risk the least?

# %%
#Optimize for maximal Sharpe ratio.
ef = EfficientFrontier(mu, S)
weights = ef.max_sharpe() #Maximize the Sharpe ratio, and get the raw weights
cleaned_weights = ef.clean_weights() 
print(cleaned_weights) #Note the weights may have some rounding error, meaning they may not add up exactly to 1 but should be close
pd.Series(cleaned_weights).plot.pie(figsize=(5,5))
# Out:
# OrderedDict([('AMRCBLF HK Equity', 0.0), ('AMRCASF HK Equity', 0.0), ('AMRDALF HK Equity', 0.0), ('AMRCGRF HK Equity', 0.0), ('AMRSGRF HK Equity', 0.85372), ('AMINAGP HK Equity', 0.14628), ('AMINASF HK Equity', 0.0), ('AMINCAA HK Equity', 0.0), ('AMINEUF HK Equity', 0.0), ('AMIGBOF HK Equity', 0.0), ('AMIHKCF HK Equity', 0.0), ('AMIMCOF HK Equity', 0.0), ('AMIT18R HK Equity', 0.0), ('AMIT28R HK Equity', 0.0), ('AMIT38R HK Equity', 0.0), ('AMIT48R HK Equity', 0.0)])

# %%
rt,vol,sharpe = ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 9.9%
# Annual volatility: 3.1%
# Sharpe Ratio: 2.57

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 1b - Long/short min variance
#
# Objective - minimising variance. There is a good deal of research that demonstrates how global-minimum variance (GMV) portfolios outperform mean-variance optimised portfolios.

# %%
S = risk_models.CovarianceShrinkage(df).ledoit_wolf()

# You don't have to provide expected returns in this case
ef = EfficientFrontier(None, S, weight_bounds=(None, None))
ef.min_volatility()
weights = ef.clean_weights()
print(weights)

pd.Series(weights).plot.barh();
# Out:
# OrderedDict([('AMRCBLF HK Equity', -0.00927), ('AMRCASF HK Equity', 0.02857), ('AMRDALF HK Equity', 0.00416), ('AMRCGRF HK Equity', -0.01101), ('AMRSGRF HK Equity', 0.0553), ('AMINAGP HK Equity', 0.20913), ('AMINASF HK Equity', -0.0016), ('AMINCAA HK Equity', -0.04585), ('AMINEUF HK Equity', -0.00035), ('AMIGBOF HK Equity', 0.02285), ('AMIHKCF HK Equity', 0.00082), ('AMIMCOF HK Equity', 0.72702), ('AMIT18R HK Equity', 0.00747), ('AMIT28R HK Equity', 0.01265), ('AMIT38R HK Equity', 0.00439), ('AMIT48R HK Equity', -0.0043)])
# C:\Users\menal\New folder\lib\site-packages\pypfopt\efficient_frontier.py:111: UserWarning: No expected returns provided. You may only use ef.min_volatility()
#   warnings.warn(

# %%
ef.portfolio_performance(verbose=True);
# Out:
# Annual volatility: 1.0%

# %%
#calculate the asset returns in our portfolio.
ret_data = df.pct_change()[1:]

#calculate the weighted returns of our assets.
weighted_returns = (weights * ret_data)

#portfolio returns are simply the sum of the weighted returns of the assets. So lets add the rows.
port_ret = weighted_returns.sum(axis=1)
print("Portfolio return (%):")
print(sum(port_ret)*100)
# Out:
# Portfolio return (%):
# 4.771147416100846

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 2a - Portfolio Optimization with given Risk Tolerance
#
# ### i.e. If your risk tolerance is higher, tell us what you expect and earn more return!

# %%
#Input your risk tolerance.
#rt = float(input("Your Risk tolerance in decimals:"))

# %%
ef = EfficientFrontier(mu, S)

ef.efficient_risk(target_volatility=0.1)                    
weights = ef.clean_weights()
weights
# Out:
# OrderedDict([('AMRCBLF HK Equity', 0.0),
#              ('AMRCASF HK Equity', 0.0),
#              ('AMRDALF HK Equity', 0.0),
#              ('AMRCGRF HK Equity', 0.0),
#              ('AMRSGRF HK Equity', 1.0),
#              ('AMINAGP HK Equity', 0.0),
#              ('AMINASF HK Equity', 0.0),
#              ('AMINCAA HK Equity', 0.0),
#              ('AMINEUF HK Equity', 0.0),
#              ('AMIGBOF HK Equity', 0.0),
#              ('AMIHKCF HK Equity', 0.0),
#              ('AMIMCOF HK Equity', 0.0),
#              ('AMIT18R HK Equity', 0.0),
#              ('AMIT28R HK Equity', 0.0),
#              ('AMIT38R HK Equity', 0.0),
#              ('AMIT48R HK Equity', 0.0)])

# %%
pd.Series(weights).plot.pie(figsize=(5,5))
plt.title("Fund Portfolio")
# Out:
# Text(0.5, 1.0, 'Fund Portfolio')

# %%
rt,vol,sharpe = ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 2b - Minimise risk for a given return

# %%
#tarret = float(input("Your target return:"))

# %%
ef = EfficientFrontier(mu, S, weight_bounds=(None, None))
ef.efficient_return(target_return=0.04, market_neutral=True)
weights = ef.clean_weights()
weights
# Out:
# OrderedDict([('AMRCBLF HK Equity', -0.00868),
#              ('AMRCASF HK Equity', -0.04021),
#              ('AMRDALF HK Equity', -0.00276),
#              ('AMRCGRF HK Equity', -0.01489),
#              ('AMRSGRF HK Equity', 0.34996),
#              ('AMINAGP HK Equity', 0.24272),
#              ('AMINASF HK Equity', -0.00188),
#              ('AMINCAA HK Equity', -0.13526),
#              ('AMINEUF HK Equity', -0.0186),
#              ('AMIGBOF HK Equity', -0.07988),
#              ('AMIHKCF HK Equity', -0.01505),
#              ('AMIMCOF HK Equity', -0.34392),
#              ('AMIT18R HK Equity', -0.02698),
#              ('AMIT28R HK Equity', 0.04946),
#              ('AMIT38R HK Equity', 0.05358),
#              ('AMIT48R HK Equity', -0.00763)])

# %%
rt,vol,sharpe = ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 4.0%
# Annual volatility: 1.1%
# Sharpe Ratio: 1.85

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Plotting Efficient Frontier

# %%
from pypfopt import CLA, plotting

cla = CLA(mu, S)
cla.max_sharpe()
cla.portfolio_performance(verbose=True);
# Out:
# Expected annual return: 7.7%
# Annual volatility: 2.3%
# Sharpe Ratio: 2.44

# %%
ax = plotting.plot_efficient_frontier(cla, showfig=False)

# %%
risktolerance, annualreturn = [], []
for rt2 in np.arange(0.012, 1, 0.001):
    ef = EfficientFrontier(mu, S)
    ef.efficient_risk(target_volatility=rt2)
    weights = ef.clean_weights()
    ret, volatility, Sharpe = ef.portfolio_performance(verbose=True)
    annualreturn.append(ret)
    risktolerance.append(rt2)
# Out:
# Expected annual return: 3.4%
# Annual volatility: 1.2%
# Sharpe Ratio: 1.19
# Expected annual return: 3.9%
# Annual volatility: 1.3%
# Sharpe Ratio: 1.47
# Expected annual return: 4.3%
# Annual volatility: 1.4%
# Sharpe Ratio: 1.67
# Expected annual return: 4.7%
# Annual volatility: 1.5%
# Sharpe Ratio: 1.83
# Expected annual return: 5.1%
# Annual volatility: 1.6%
# Sharpe Ratio: 1.96
# Expected annual return: 5.5%
# Annual volatility: 1.7%
# Sharpe Ratio: 2.06
# Expected annual return: 5.9%
# Annual volatility: 1.8%
# Sharpe Ratio: 2.15
# Expected annual return: 6.2%
# Annual volatility: 1.9%
# Sharpe Ratio: 2.22
# Expected annual return: 6.6%
# Annual volatility: 2.0%
# Sharpe Ratio: 2.28
# Expected annual return: 6.9%
# Annual volatility: 2.1%
# Sharpe Ratio: 2.34
# Expected annual return: 7.2%
# Annual volatility: 2.2%
# Sharpe Ratio: 2.38
# Expected annual return: 7.6%
# Annual volatility: 2.3%
# Sharpe Ratio: 2.43
# Expected annual return: 7.9%
# Annual volatility: 2.4%
# Sharpe Ratio: 2.46
# Expected annual return: 8.2%
# Annual volatility: 2.5%
# Sharpe Ratio: 2.49
# Expected annual return: 8.6%
# Annual volatility: 2.6%
# Sharpe Ratio: 2.52
# Expected annual return: 8.9%
# Annual volatility: 2.7%
# Sharpe Ratio: 2.54
# Expected annual return: 9.2%
# Annual volatility: 2.8%
# Sharpe Ratio: 2.56
# Expected annual return: 9.4%
# Annual volatility: 2.9%
# Sharpe Ratio: 2.57
# Expected annual return: 9.7%
# Annual volatility: 3.0%
# Sharpe Ratio: 2.57
# Expected annual return: 10.0%
# Annual volatility: 3.1%
# Sharpe Ratio: 2.57
# Expected annual return: 10.2%
# Annual volatility: 3.2%
# Sharpe Ratio: 2.57
# Expected annual return: 10.5%
# Annual volatility: 3.3%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# ...
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56
# Expected annual return: 10.6%
# Annual volatility: 3.4%
# Sharpe Ratio: 2.56

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # This scheme in a nutshell:

# %%
plt.plot(annualreturn, risktolerance)

# %% [markdown]
# ##         Any portfolio with volatility higher than 3.4% is bad because you earn the same afterwards. The highest return you can get is 10.6%.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Function 3 - Discrete Allocation of each fund
#
# ### i.e. How many shares for each fund should I buy?

# %%
#Input amount of your portfolio
tpv = float(input("Amount of your portfolio:"))
# Out:
# Amount of your portfolio:15000

# %%
#!pip install pulp
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
latest_prices = get_latest_prices(df)
print("Latest Price of all funds")
latest_prices
# Out:
# Latest Price of all funds
# AMRCBLF HK Equity    16.4500
# AMRCASF HK Equity    13.4300
# AMRDALF HK Equity    13.1900
# AMRCGRF HK Equity    18.0500
# AMRSGRF HK Equity    15.0000
# AMINAGP HK Equity    11.6575
# AMINASF HK Equity    17.5798
# AMINCAA HK Equity    12.0833
# AMINEUF HK Equity    14.2983
# AMIGBOF HK Equity    11.5579
# AMIHKCF HK Equity    16.9242
# AMIMCOF HK Equity    10.1910
# AMIT18R HK Equity    14.2689
# AMIT28R HK Equity    15.4083
# AMIT38R HK Equity    16.8911
# AMIT48R HK Equity    17.6765
# Name: 2020-07-31 00:00:00, dtype: float64

# %%
cleaned_weights = ef.clean_weights()
weights = cleaned_weights 
da = DiscreteAllocation(weights, latest_prices, total_portfolio_value=tpv)   
allocation, leftover = da.lp_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: ${:.2f}".format(leftover))
# Out:
# Discrete allocation: {'AMRSGRF HK Equity': 1000}
# Funds remaining: $0.00

# %%
pd.Series(weights).plot.barh()
plt.xlabel('Weight of each fund')
# Out:
# Text(0.5, 0, 'Weight of each fund')
